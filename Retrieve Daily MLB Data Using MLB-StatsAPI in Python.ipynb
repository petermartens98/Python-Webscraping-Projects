# %% [markdown]
# ## Daily MLB Data Retrieval and EDA Using MLB-StatsAPI

# %% [markdown]
# MLB-StatsAPI wiki: https://github.com/toddrob99/MLB-StatsAPI/wiki

# %% [markdown]
# ### Import neccesary modules

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import datetime

import statsmodels.api as sm
from statsmodels.sandbox.predict_functional import predict_functional

# import MLB-StatsAPI module
import statsapi

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ### Leagues ID
# ##### American League = 103
# ##### National League = 104
#
# ### Divisions ID
# ##### AL West = 200
# ##### AL East = 201
# ##### AL Central = 202
# ##### NL West = 203
# ##### NL East = 204
# ##### NL Central = 205

# %% [markdown]
# ### Functions that returns current division standings from MLB-StatsAPI

# %%
def get_division_standings(league, division): 
    standings = pd.DataFrame(statsapi.standings_data(league)[division]['teams'])
    standings = standings[['div_rank', 'name', 'w', 'l', 'gb', 'elim_num', 'wc_rank', 'wc_gb', 'wc_elim_num' ]]
    return standings

get_division_standings(103,202)
# Out:
#   div_rank                 name   w   l    gb elim_num wc_rank wc_gb  \
# 0        1      Minnesota Twins  52  46     -        -       -     -
# 1        2  Cleveland Guardians  50  47   1.5       64       4   2.5
# 2        3    Chicago White Sox  49  49   3.0       62       6   4.0
# 3        4       Detroit Tigers  40  59  12.5       52      10  13.5
# 4        5   Kansas City Royals  39  59  13.0       52      11  14.0
#
#   wc_elim_num
# 0           -
# 1          63
# 2          61
# 3          51
# 4          51

# %%
def get_all_division_standings():
    print('\033[1;4m' + "Major League Standings for {}".format(datetime.datetime.now().strftime('%m-%d-%Y')) + '\033[0m')
    print()
    print('\033[1m' + 'American League Standings' + '\033[0m')
    print(statsapi.standings(103))
    print('\033[1m' + 'National League Standings' + '\033[0m')
    print(statsapi.standings(104))
    
get_all_division_standings()
# Out:
# Major League Standings for 07-28-2022
#
# American League Standings
# American League East
# Rank Team                   W   L   GB  (E#) WC Rank WC GB (E#)
#  1   New York Yankees      66  33   -    -      -      -    -
#  2   Toronto Blue Jays     54  44  11.5  53     1    +1.0   -
#  3   Tampa Bay Rays        53  45  12.5  52     3      -    -
#  4   Baltimore Orioles     49  49  16.5  48     5     4.0   61
#  5   Boston Red Sox        49  50  17.0  47     7     4.5   60
#
# American League Central
# Rank Team                   W   L   GB  (E#) WC Rank WC GB (E#)
#  1   Minnesota Twins       52  46   -    -      -      -    -
#  2   Cleveland Guardians   50  47  1.5   64     4     2.5   63
#  3   Chicago White Sox     49  49  3.0   62     6     4.0   61
#  4   Detroit Tigers        40  59  12.5  52    10    13.5   51
#  5   Kansas City Royals    39  59  13.0  52    11    14.0   51
#
# American League West
# Rank Team                   W   L   GB  (E#) WC Rank WC GB (E#)
#  1   Houston Astros        64  35   -    -      -      -    -
#  2   Seattle Mariners      54  45  10.0  54     2    +0.5   -
#  3   Texas Rangers         43  54  20.0  45     8     9.5   56
#  4   Los Angeles Angels    42  56  21.5  43     9    11.0   54
#  5   Oakland Athletics     38  63  27.0  36    12    16.5   47
#
#
# National League Standings
# National League East
# Rank Team                   W   L   GB  (E#) WC Rank WC GB (E#)
#  1   New York Mets         61  37   -    -      -      -    -
#  2   Atlanta Braves        59  41  3.0   61     1    +6.5   -
#  3   Philadelphia Phillies 51  47  10.0  55     4     0.5   64
#  4   Miami Marlins         46  52  15.0  50     6     5.5   59
#  5   Washington Nationals  34  66  28.0  36    12    18.5   45
#
# National League Central
# Rank Team                   W   L   GB  (E#) WC Rank WC GB (E#)
#  1   Milwaukee Brewers     55  44   -    -      -      -    -
#  2   St. Louis Cardinals   52  47  3.0   61     3      -    -
#  3   Chicago Cubs          40  57  14.0  51     9    11.0   54
#  4   Pittsburgh Pirates    40  58  14.5  50    10    11.5   53
#  5   Cincinnati Reds       38  59  16.0  49    11    13.0   52
#
# National League West
# Rank Team                   W   L   GB  (E#) WC Rank WC GB (E#)
#  1   Los Angeles Dodgers   65  32   -    -      -      -    -
#  2   San Diego Padres      55  45  11.5  53     2    +2.5   -
#  3   San Francisco Giants  48  50  17.5  48     5     3.5   61
#  4   Arizona Diamondbacks  45  53  20.5  45     7     6.5   58
#  5   Colorado Rockies      45  54  21.0  44     8     7.0   57

# %% [markdown]
# ### Functions that returns current HR leaders for whole MLB and also for only rookies

# %%
def current_hr_leaders():
    hr_leaders = statsapi.league_leaders('homeRuns',season = 2022, limit = 5).split('\n')
    return hr_leaders

#current_hr_leaders()

# %%
# Another possibility for current_hr_leaders() function
def current_hr_leaders():
    print('\033[1m' + 'MLB Home Run Leaders' + '\033[0m')
    print(statsapi.league_leaders('homeRuns',season = 2022, limit = 5))
current_hr_leaders()
# Out:
# MLB Home Run Leaders
# Rank Name                 Team                    Value
#  1   Aaron Judge          New York Yankees         38
#  2   Kyle Schwarber       Philadelphia Phillies    31
#  3   Yordan Alvarez       Houston Astros           29
#  4   Austin Riley         Atlanta Braves           28
#  5   Pete Alonso          New York Mets            26

# %%
def current_rookie_hr_leaders():
    rookie_hr_leaders = statsapi.league_leaders('homeRuns',season = 2022, playerPool = 'rookies',limit = 5)
    rookie_hr_leaders = rookie_hr_leaders.split('\n')
    return rookie_hr_leaders

current_rookie_hr_leaders()
# Out:
# ['Rank Name                 Team                    Value',
#  ' 1   Julio Rodriguez      Seattle Mariners         18  ',
#  ' 2   Jeremy Pena          Houston Astros           15  ',
#  ' 3   Jack Suwinski        Pittsburgh Pirates       14  ',
#  ' 3   Bobby Witt Jr.       Kansas City Royals       14  ',
#  ' 5   Juan Yepez           St. Louis Cardinals      11  ',
#  '']

# %% [markdown]
# ### Function that returns current RBI leaders

# %%
def current_rbi_leaders():
    print('\033[1m' + 'MLB RBI Leaders' + '\033[0m')
    print(statsapi.league_leaders('RBI',season = 2022, limit = 5))
current_rbi_leaders()
# Out:
# MLB RBI Leaders
# Rank Name                 Team                    Value
#  1   Pete Alonso          New York Mets            84
#  2   Aaron Judge          New York Yankees         82
#  3   Jose Ramirez         Cleveland Guardians      79
#  4   Paul Goldschmidt     St. Louis Cardinals      77
#  5   C.J. Cron            Colorado Rockies         71

# %% [markdown]
# ### Function that returns current hits leaders

# %%
def current_hits_leaders():
    print('\033[1m' + 'MLB Hits Leaders' + '\033[0m')
    print(statsapi.league_leaders('Hits',season = 2022, limit = 5))
current_hits_leaders()
# Out:
# MLB Hits Leaders
# Rank Name                 Team                    Value
#  1   Freddie Freeman      Los Angeles Dodgers      122
#  2   Trea Turner          Los Angeles Dodgers      121
#  3   Paul Goldschmidt     St. Louis Cardinals      118
#  4   Rafael Devers        Boston Red Sox           113
#  4   Austin Riley         Atlanta Braves           113
#  4   Dansby Swanson       Atlanta Braves           113

# %% [markdown]
# ### Functions that return current ERA leaders

# %%
def current_era_leaders():
    era_leaders = statsapi.league_leaders('ERA',season = 2022, limit = 5)
    era_leaders = era_leaders.split('\n')
    return era_leaders

#current_era_leaders()

# %%
# Another possibility for current_era_leaders() function
def current_era_leaders():
    print('\033[1m' + 'MLB ERA Leaders' + '\033[0m')
    print(statsapi.league_leaders('ERA',season = 2022, limit = 5))

current_era_leaders()
# Out:
# MLB ERA Leaders
# Rank Name                 Team                    Value
#  1   Shane McClanahan     Tampa Bay Rays          1.76
#  2   Sandy Alcantara      Miami Marlins           1.81
#  3   Justin Verlander     Houston Astros          1.86
#  4   Dylan Cease          Chicago White Sox       2.03
#  5   Alek Manoah          Toronto Blue Jays       2.24

# %% [markdown]
# ### Function that retuerns current WHIP leaders

# %%
def current_whip_leaders():
    print('\033[1m' + 'MLB WHIP Leaders' + '\033[0m')
    print(statsapi.league_leaders('WHIP',season = 2022, limit = 5))
current_whip_leaders()
# Out:
# MLB WHIP Leaders
# Rank Name                 Team                    Value
#  1   Shane McClanahan     Tampa Bay Rays          0.77
#  2   Justin Verlander     Houston Astros          0.88
#  3   Tony Gonsolin        Los Angeles Dodgers     0.88
#  4   Sandy Alcantara      Miami Marlins           0.90
#  5   Corbin Burnes        Milwaukee Brewers       0.92

# %% [markdown]
# ### Function that returns current Strike Out leaders

# %%
def current_SO_leaders():
    print('\033[1m' + 'MLB Strike Out Leaders' + '\033[0m')
    print(statsapi.league_leaders('strikeouts',season = 2022, limit = 5))
current_SO_leaders()
# Out:
# MLB Strike Out Leaders
# Rank Name                 Team                    Value
#  1   Eugenio Suarez       Seattle Mariners         134
#  2   Patrick Wisdom       Chicago Cubs             129
#  3   Kyle Schwarber       Philadelphia Phillies    128
#  4   Brandon Marsh        Los Angeles Angels       114
#  5   C.J. Cron            Colorado Rockies         110
#  5   Adolis Garcia        Texas Rangers            110
#  5   Aaron Judge          New York Yankees         110
#  5   Dansby Swanson       Atlanta Braves           110

# %% [markdown]
# ### Daily Summary for MLB Standings and League Leaders

# %%
def daily_summary():
    print(('\033[1;4m' + "Major League Daily Summary for {}".
          format(datetime.datetime.now().strftime('%m-%d-%Y')) + '\033[0m'))
    print()
    get_all_division_standings()
    print('\033[1;4m' + "Major League Stats Leaders for {}".
          format(datetime.datetime.now().strftime('%m-%d-%Y')) + '\033[0m')
    print()
    print('\033[1;4m' + "Offensive Stats Leaders" + '\033[0m')
    print()
    current_hr_leaders()
    current_rbi_leaders()
    current_hits_leaders()
    print('\033[1;4m' + "Pitching Stats Leaders" + '\033[0m')
    print()
    current_era_leaders()
    current_whip_leaders()
    current_SO_leaders()

# %%
daily_summary()
# Out:
# Major League Daily Summary for 07-28-2022
#
# Major League Standings for 07-28-2022
#
# American League Standings
# American League East
# Rank Team                   W   L   GB  (E#) WC Rank WC GB (E#)
#  1   New York Yankees      66  33   -    -      -      -    -
#  2   Toronto Blue Jays     54  44  11.5  53     1    +1.0   -
#  3   Tampa Bay Rays        53  45  12.5  52     3      -    -
#  4   Baltimore Orioles     49  49  16.5  48     5     4.0   61
#  5   Boston Red Sox        49  50  17.0  47     7     4.5   60
#
# American League Central
# Rank Team                   W   L   GB  (E#) WC Rank WC GB (E#)
#  1   Minnesota Twins       52  46   -    -      -      -    -
#  2   Cleveland Guardians   50  47  1.5   64     4     2.5   63
#  3   Chicago White Sox     49  49  3.0   62     6     4.0   61
#  4   Detroit Tigers        40  59  12.5  52    10    13.5   51
#  5   Kansas City Royals    39  59  13.0  52    11    14.0   51
#
# American League West
# Rank Team                   W   L   GB  (E#) WC Rank WC GB (E#)
#  1   Houston Astros        64  35   -    -      -      -    -
#  2   Seattle Mariners      54  45  10.0  54     2    +0.5   -
#  3   Texas Rangers         43  54  20.0  45     8     9.5   56
#  4   Los Angeles Angels    42  56  21.5  43     9    11.0   54
#  5   Oakland Athletics     38  63  27.0  36    12    16.5   47
#
#
# National League Standings
# National League East
# Rank Team                   W   L   GB  (E#) WC Rank WC GB (E#)
#  1   New York Mets         61  37   -    -      -      -    -
#  2   Atlanta Braves        59  41  3.0   61     1    +6.5   -
#  3   Philadelphia Phillies 51  47  10.0  55     4     0.5   64
#  4   Miami Marlins         46  52  15.0  50     6     5.5   59
#  5   Washington Nationals  34  66  28.0  36    12    18.5   45
#
# National League Central
# Rank Team                   W   L   GB  (E#) WC Rank WC GB (E#)
#  1   Milwaukee Brewers     55  44   -    -      -      -    -
#  2   St. Louis Cardinals   52  47  3.0   61     3      -    -
#  3   Chicago Cubs          40  57  14.0  51     9    11.0   54
#  4   Pittsburgh Pirates    40  58  14.5  50    10    11.5   53
#  5   Cincinnati Reds       38  59  16.0  49    11    13.0   52
#
# National League West
# Rank Team                   W   L   GB  (E#) WC Rank WC GB (E#)
#  1   Los Angeles Dodgers   65  32   -    -      -      -    -
#  2   San Diego Padres      55  45  11.5  53     2    +2.5   -
#  3   San Francisco Giants  48  50  17.5  48     5     3.5   61
#  4   Arizona Diamondbacks  45  53  20.5  45     7     6.5   58
#  5   Colorado Rockies      45  54  21.0  44     8     7.0   57
#
#
# Major League Stats Leaders for 07-28-2022
#
# Offensive Stats Leaders
#
# MLB Home Run Leaders
# Rank Name                 Team                    Value
#  1   Aaron Judge          New York Yankees         38
#  2   Kyle Schwarber       Philadelphia Phillies    31
#  3   Yordan Alvarez       Houston Astros           29
#  4   Austin Riley         Atlanta Braves           28
#  5   Pete Alonso          New York Mets            26
#
# MLB RBI Leaders
# Rank Name                 Team                    Value
#  1   Pete Alonso          New York Mets            84
#  2   Aaron Judge          New York Yankees         82
#  3   Jose Ramirez         Cleveland Guardians      79
#  4   Paul Goldschmidt     St. Louis Cardinals      77
#  5   C.J. Cron            Colorado Rockies         71
#
# MLB Hits Leaders
# Rank Name                 Team                    Value
#  1   Freddie Freeman      Los Angeles Dodgers      122
#  2   Trea Turner          Los Angeles Dodgers      121
#  3   Paul Goldschmidt     St. Louis Cardinals      118
#  4   Rafael Devers        Boston Red Sox           113
#  4   Austin Riley         Atlanta Braves           113
#  4   Dansby Swanson       Atlanta Braves           113
#
# Pitching Stats Leaders
#
# MLB ERA Leaders
# Rank Name                 Team                    Value
#  1   Shane McClanahan     Tampa Bay Rays          1.76
#  2   Sandy Alcantara      Miami Marlins           1.81
#  3   Justin Verlander     Houston Astros          1.86
#  4   Dylan Cease          Chicago White Sox       2.03
#  5   Alek Manoah          Toronto Blue Jays       2.24
#
# MLB WHIP Leaders
# Rank Name                 Team                    Value
#  1   Shane McClanahan     Tampa Bay Rays          0.77
#  2   Justin Verlander     Houston Astros          0.88
#  3   Tony Gonsolin        Los Angeles Dodgers     0.88
#  4   Sandy Alcantara      Miami Marlins           0.90
#  5   Corbin Burnes        Milwaukee Brewers       0.92
#
# MLB Strike Out Leaders
# Rank Name                 Team                    Value
#  1   Eugenio Suarez       Seattle Mariners         134
#  2   Patrick Wisdom       Chicago Cubs             129
#  3   Kyle Schwarber       Philadelphia Phillies    128
#  4   Brandon Marsh        Los Angeles Angels       114
#  5   C.J. Cron            Colorado Rockies         110
#  5   Adolis Garcia        Texas Rangers            110
#  5   Aaron Judge          New York Yankees         110
#  5   Dansby Swanson       Atlanta Braves           110

# %%
statsapi.standings_data(leagueId="103,104", division="all", include_wildcard=True, season=None, standingsTypes=None, date=None)
# Out:
# {201: {'div_name': 'American League East',
#   'teams': [{'name': 'New York Yankees',
#     'div_rank': '1',
#     'w': 66,
#     'l': 33,
#     'gb': '-',
#     'wc_rank': '-',
#     'wc_gb': '-',
#     'wc_elim_num': '-',
#     'elim_num': '-',
#     'team_id': 147,
#     'league_rank': '1',
#     'sport_rank': '2'},
#    {'name': 'Toronto Blue Jays',
#     'div_rank': '2',
#     'w': 54,
#     'l': 44,
#     'gb': '11.5',
#     'wc_rank': '1',
#     'wc_gb': '+1.0',
#     'wc_elim_num': '-',
#     'elim_num': '53',
#     'team_id': 141,
#     'league_rank': '3',
#     'sport_rank': '7'},
#    {'name': 'Tampa Bay Rays',
#     'div_rank': '3',
#     'w': 53,
#     'l': 45,
#     'gb': '12.5',
#     'wc_rank': '3',
#     'wc_gb': '-',
#     'wc_elim_num': '-',
#     'elim_num': '52',
#     'team_id': 139,
#     'league_rank': '5',
#     'sport_rank': '10'},
#    {'name': 'Baltimore Orioles',
#     'div_rank': '4',
#     'w': 49,
#     'l': 49,
#     'gb': '16.5',
#     'wc_rank': '5',
#     'wc_gb': '4.0',
#     'wc_elim_num': '61',
#     'elim_num': '48',
#     'team_id': 110,
#     'league_rank': '8',
#     'sport_rank': '15'},
#    {'name': 'Boston Red Sox',
#     'div_rank': '5',
#     'w': 49,
#     'l': 50,
#     'gb': '17.0',
#     'wc_rank': '7',
#     'wc_gb': '4.5',
#     'wc_elim_num': '60',
#     'elim_num': '47',
#     'team_id': 111,
#     'league_rank': '10',
#     'sport_rank': '17'}]},
#  202: {'div_name': 'American League Central',
#   'teams': [{'name': 'Minnesota Twins',
#     'div_rank': '1',
#     'w': 52,
#     'l': 46,
#     'gb': '-',
#     'wc_rank': '-',
#     'wc_gb': '-',
#     'wc_elim_num': '-',
#     'elim_num': '-',
#     'team_id': 142,
#     'league_rank': '6',
#     'sport_rank': '11'},
#    {'name': 'Cleveland Guardians',
#     'div_rank': '2',
#     'w': 50,
#     'l': 47,
#     'gb': '1.5',
#     'wc_rank': '4',
#     'wc_gb': '2.5',
#     'wc_elim_num': '63',
#     'elim_num': '64',
#     'team_id': 114,
#     'league_rank': '7',
#     'sport_rank': '14'},
#    {'name': 'Chicago White Sox',
#     'div_rank': '3',
#     'w': 49,
#     'l': 49,
#     'gb': '3.0',
#     'wc_rank': '6',
#     'wc_gb': '4.0',
#     'wc_elim_num': '61',
#     'elim_num': '62',
#     'team_id': 145,
#     'league_rank': '9',
#     'sport_rank': '16'},
#    {'name': 'Detroit Tigers',
#     'div_rank': '4',
#     'w': 40,
#     'l': 59,
#     'gb': '12.5',
#     'wc_rank': '10',
#     'wc_gb': '13.5',
#     'wc_elim_num': '51',
#     'elim_num': '52',
#     'team_id': 116,
#     'league_rank': '13',
#     'sport_rank': '26'},
#    {'name': 'Kansas City Royals',
#     'div_rank': '5',
#     'w': 39,
#     'l': 59,
#     'gb': '13.0',
#     'wc_rank': '11',
#     'wc_gb': '14.0',
#     'wc_elim_num': '51',
#     'elim_num': '52',
#     'team_id': 118,
#     'league_rank': '14',
#     'sport_rank': '27'}]},
#  200: {'div_name': 'American League West',
#   'teams': [{'name': 'Houston Astros',
#     'div_rank': '1',
#     'w': 64,
#     'l': 35,
#     'gb': '-',
#     'wc_rank': '-',
#     'wc_gb': '-',
#     'wc_elim_num': '-',
#     'elim_num': '-',
#     'team_id': 117,
#     'league_rank': '2',
#     'sport_rank': '3'},
#    {'name': 'Seattle Mariners',
#     'div_rank': '2',
#     'w': 54,
#     'l': 45,
#     'gb': '10.0',
#     'wc_rank': '2',
#     'wc_gb': '+0.5',
#     'wc_elim_num': '-',
#     'elim_num': '54',
#     'team_id': 136,
#     'league_rank': '4',
#     'sport_rank': '9'},
#    {'name': 'Texas Rangers',
#     'div_rank': '3',
#     'w': 43,
#     'l': 54,
#     'gb': '20.0',
#     'wc_rank': '8',
#     'wc_gb': '9.5',
#     'wc_elim_num': '56',
#     'elim_num': '45',
#     'team_id': 140,
#     'league_rank': '11',
#     'sport_rank': '22'},
#    {'name': 'Los Angeles Angels',
#     'div_rank': '4',
#     'w': 42,
#     'l': 56,
#     'gb': '21.5',
#     'wc_rank': '9',
#     'wc_gb': '11.0',
#     'wc_elim_num': '54',
#     'elim_num': '43',
#     'team_id': 108,
#     'league_rank': '12',
#     'sport_rank': '23'},
#    {'name': 'Oakland Athletics',
#     'div_rank': '5',
#     'w': 38,
#     'l': 63,
#     'gb': '27.0',
#     'wc_rank': '12',
#     'wc_gb': '16.5',
#     'wc_elim_num': '47',
#     'elim_num': '36',
#     'team_id': 133,
#     'league_rank': '15',
#     'sport_rank': '29'}]},
#  204: {'div_name': 'National League East',
#   'teams': [{'name': 'New York Mets',
#     'div_rank': '1',
#     'w': 61,
#     'l': 37,
#     'gb': '-',
#     'wc_rank': '-',
#     'wc_gb': '-',
#     'wc_elim_num': '-',
#     'elim_num': '-',
#     'team_id': 121,
#     'league_rank': '2',
#     'sport_rank': '4'},
#    {'name': 'Atlanta Braves',
#     'div_rank': '2',
#     'w': 59,
#     'l': 41,
#     'gb': '3.0',
#     'wc_rank': '1',
#     'wc_gb': '+6.5',
#     'wc_elim_num': '-',
#     'elim_num': '61',
#     'team_id': 144,
#     'league_rank': '3',
#     'sport_rank': '5'},
#    {'name': 'Philadelphia Phillies',
#     'div_rank': '3',
#     'w': 51,
#     'l': 47,
#     'gb': '10.0',
#     'wc_rank': '4',
#     'wc_gb': '0.5',
#     'wc_elim_num': '64',
#     'elim_num': '55',
#     'team_id': 143,
#     'league_rank': '7',
#     'sport_rank': '13'},
#    {'name': 'Miami Marlins',
#     'div_rank': '4',
#     'w': 46,
#     'l': 52,
#     'gb': '15.0',
#     'wc_rank': '6',
#     'wc_gb': '5.5',
#     'wc_elim_num': '59',
#     'elim_num': '50',
#     'team_id': 146,
#     'league_rank': '9',
#     'sport_rank': '19'},
#    {'name': 'Washington Nationals',
#     'div_rank': '5',
#     'w': 34,
#     'l': 66,
#     'gb': '28.0',
#     'wc_rank': '12',
#     'wc_gb': '18.5',
#     'wc_elim_num': '45',
#     'elim_num': '36',
#     'team_id': 120,
#     'league_rank': '15',
#     'sport_rank': '30'}]},
#  205: {'div_name': 'National League Central',
#   'teams': [{'name': 'Milwaukee Brewers',
#     'div_rank': '1',
#     'w': 55,
#     'l': 44,
#     'gb': '-',
#     'wc_rank': '-',
#     'wc_gb': '-',
#     'wc_elim_num': '-',
#     'elim_num': '-',
#     'team_id': 158,
#     'league_rank': '4',
#     'sport_rank': '6'},
#    {'name': 'St. Louis Cardinals',
#     'div_rank': '2',
#     'w': 52,
#     'l': 47,
#     'gb': '3.0',
#     'wc_rank': '3',
#     'wc_gb': '-',
#     'wc_elim_num': '-',
#     'elim_num': '61',
#     'team_id': 138,
#     'league_rank': '6',
#     'sport_rank': '12'},
#    {'name': 'Chicago Cubs',
#     'div_rank': '3',
#     'w': 40,
#     'l': 57,
#     'gb': '14.0',
#     'wc_rank': '9',
#     'wc_gb': '11.0',
#     'wc_elim_num': '54',
#     'elim_num': '51',
#     'team_id': 112,
#     'league_rank': '12',
#     'sport_rank': '24'},
#    {'name': 'Pittsburgh Pirates',
#     'div_rank': '4',
#     'w': 40,
#     'l': 58,
#     'gb': '14.5',
#     'wc_rank': '10',
#     'wc_gb': '11.5',
#     'wc_elim_num': '53',
#     'elim_num': '50',
#     'team_id': 134,
#     'league_rank': '13',
#     'sport_rank': '25'},
#    {'name': 'Cincinnati Reds',
#     'div_rank': '5',
#     'w': 38,
#     'l': 59,
#     'gb': '16.0',
#     'wc_rank': '11',
#     'wc_gb': '13.0',
#     'wc_elim_num': '52',
#     'elim_num': '49',
#     'team_id': 113,
#     'league_rank': '14',
#     'sport_rank': '28'}]},
#  203: {'div_name': 'National League West',
#   'teams': [{'name': 'Los Angeles Dodgers',
#     'div_rank': '1',
#     'w': 65,
#     'l': 32,
#     'gb': '-',
#     'wc_rank': '-',
#     'wc_gb': '-',
#     'wc_elim_num': '-',
#     'elim_num': '-',
#     'team_id': 119,
#     'league_rank': '1',
#     'sport_rank': '1'},
#    {'name': 'San Diego Padres',
#     'div_rank': '2',
#     'w': 55,
#     'l': 45,
#     'gb': '11.5',
#     'wc_rank': '2',
#     'wc_gb': '+2.5',
#     'wc_elim_num': '-',
#     'elim_num': '53',
#     'team_id': 135,
#     'league_rank': '5',
#     'sport_rank': '8'},
#    {'name': 'San Francisco Giants',
#     'div_rank': '3',
#     'w': 48,
#     'l': 50,
#     'gb': '17.5',
#     'wc_rank': '5',
#     'wc_gb': '3.5',
#     'wc_elim_num': '61',
#     'elim_num': '48',
#     'team_id': 137,
#     'league_rank': '8',
#     'sport_rank': '18'},
#    {'name': 'Arizona Diamondbacks',
#     'div_rank': '4',
#     'w': 45,
#     'l': 53,
#     'gb': '20.5',
#     'wc_rank': '7',
#     'wc_gb': '6.5',
#     'wc_elim_num': '58',
#     'elim_num': '45',
#     'team_id': 109,
#     'league_rank': '10',
#     'sport_rank': '20'},
#    {'name': 'Colorado Rockies',
#     'div_rank': '5',
#     'w': 45,
#     'l': 54,
#     'gb': '21.0',
#     'wc_rank': '8',
#     'wc_gb': '7.0',
#     'wc_elim_num': '57',
#     'elim_num': '44',
#     'team_id': 115,
#     'league_rank': '11',
#     'sport_rank': '21'}]}}
